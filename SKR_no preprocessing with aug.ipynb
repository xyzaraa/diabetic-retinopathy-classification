# %% [markdown]
# # RESNET50

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import warnings
import seaborn as sns
import cv2 as cv2
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import confusion_matrix, f1_score, classification_report
warnings.filterwarnings('ignore')
tf.keras.backend.clear_session()

# %% [markdown]
# ## Load Images

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
df["id_code"] = df["id_code"].astype(str) + ".png"
label_map = dict(zip(df["id_code"], df["diagnosis"]))
dataset_path = 'colored_images'
X = []
y = []

# %%
df.head()
# Out:
#             id_code  diagnosis
# 0  000c1434d8d7.png          2
# 1  001639a390f0.png          4
# 2  0024cdab0c1e.png          1
# 3  002c21358ce6.png          0
# 4  005b95c28852.png          0

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):
        print(f"🔄 Loading images from {subfolder}...")

        for filename in tqdm(os.listdir(subfolder_path)):
            img_path = os.path.join(subfolder_path, filename)

          
            if filename in label_map:
                label = label_map[filename] 
                
                # Load gambar
                img = cv2.imread(img_path)
                if img is not None:
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    img = cv2.resize(img, (224, 224))  
                    X.append(img)
                    y.append(label) 

print(f"Total images loaded: {len(X)}")
print(f"Total labels loaded: {len(y)}")
# Out:
# 🔄 Loading images from Mild...
# 100%|██████████| 370/370 [00:00<00:00, 548.47it/s]
# 🔄 Loading images from Moderate...
# 100%|██████████| 999/999 [00:02<00:00, 476.84it/s]
# 🔄 Loading images from No_DR...
# 100%|██████████| 1805/1805 [00:02<00:00, 609.73it/s]
# 🔄 Loading images from Proliferate_DR...
# 100%|██████████| 295/295 [00:00<00:00, 624.40it/s]
# 🔄 Loading images from Severe...
# 100%|██████████| 193/193 [00:00<00:00, 591.86it/s]
# Total images loaded: 3662
# Total labels loaded: 3662

# %%
import random

random_indices = random.sample(range(len(X)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X[index])
    plt.title(f"Label: {y[index]}")
    plt.axis('off')
plt.show()

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):  # Cek apakah benar-benar folder
        count = len([name for name in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, name))])
        print(f'Jumlah gambar pada folder {subfolder}: {count}')
# Out:
# Jumlah gambar pada folder Mild: 370
# Jumlah gambar pada folder Moderate: 999
# Jumlah gambar pada folder No_DR: 1805
# Jumlah gambar pada folder Proliferate_DR: 295
# Jumlah gambar pada folder Severe: 193

# %% [markdown]
# ## Splitting Data

# %%
X = np.array(X)
y = np.array(y)

X_train, X_remainingdata, y_train, y_remainingdata = train_test_split(X, y, train_size=0.6, random_state=42, stratify=y)
X_valid, X_test, y_valid, y_test = train_test_split(X_remainingdata, y_remainingdata, test_size=0.25, random_state=42, stratify=y_remainingdata)

print(f"Ukuran data training: {len(X_train)}")
print(f"Ukuran data validasi: {len(X_valid)}")
print(f"Ukuran data testing: {len(X_test)}")
# Out:
# Ukuran data training: 2197
# Ukuran data validasi: 1098
# Ukuran data testing: 367

# %%
print(X_train.shape)
# Out:
# (2197, 224, 224, 3)

# %%
from collections import Counter
print("\nDistribusi kelas :")
print("Training:", Counter(y_train))
print("Validation:", Counter(y_valid))
print("Testing:", Counter(y_test))
# Out:
# Distribusi kelas :
# Training: Counter({0: 1083, 2: 599, 1: 222, 4: 177, 3: 116})
# Validation: Counter({0: 541, 2: 300, 1: 111, 4: 88, 3: 58})
# Testing: Counter({0: 181, 2: 100, 1: 37, 4: 30, 3: 19})

# %%
import albumentations as A
def augment_image(image):
    # Definisikan augmentasi
    augmentations = A.Compose([
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.RandomRotate90(p=0.5),
        A.RandomBrightnessContrast(p=0.2),
        A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, p=0.5),
        A.GaussianBlur(blur_limit=(3, 7), p=0.5),
        A.Emboss(p=0.5),
        # Hapus RandomScale dan PadIfNeeded
    ])

    augmented = augmentations(image=image)['image']
    
    # Resize kembali ke ukuran yang diinginkan
    augmented_resized = cv2.resize(augmented, (224, 224))

    # Pastikan dimensi output konsisten
    if augmented_resized.shape != (224, 224, 3):
        raise ValueError(f"Output shape is not as expected: {augmented_resized.shape}")

    return augmented_resized

# %%
X_train_augmented = []

for image in X_train:
    augmented_image = augment_image(image)
    X_train_augmented.append(augmented_image)

# Mengubah kembali ke array NumPy jika diperlukan
X_train_augmented = np.array(X_train_augmented)

# %% [markdown]
# ## Build Model ResNet50

# %%
n_class = 5

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
for layer in base_model.layers: 
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(n_class, activation='softmax')(x)

adam = Adam(lr=0.00001)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision()])

# %%
from keras.utils import to_categorical

y_train_one_hot = to_categorical(y_train, num_classes=n_class)
y_valid_one_hot = to_categorical(y_valid, num_classes=n_class)
y_test_one_hot = to_categorical(y_test, num_classes=n_class )

# %%
print(X_train.shape)
print(y_train_one_hot.shape)
print(X_valid.shape)
print(y_valid_one_hot.shape)
# Out:
# (2197, 224, 224, 3)
# (2197, 5)
# (1098, 224, 224, 3)
# (1098, 5)

# %%
history = model.fit(X_train_augmented, y_train_one_hot, epochs=32, batch_size=8, validation_data=(X_valid, y_valid_one_hot))
# Out:
# Epoch 1/32
# 275/275 [==============================] - 17s 39ms/step - loss: 1.4083 - accuracy: 0.4570 - recall: 0.1966 - precision: 0.6025 - val_loss: 1.0945 - val_accuracy: 0.6056 - val_recall: 0.5137 - val_precision: 0.7560
# Epoch 2/32
# 275/275 [==============================] - 10s 37ms/step - loss: 1.1156 - accuracy: 0.6199 - recall: 0.4238 - precision: 0.7490 - val_loss: 0.9474 - val_accuracy: 0.6566 - val_recall: 0.5692 - val_precision: 0.7594
# Epoch 3/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.9968 - accuracy: 0.6495 - recall: 0.4902 - precision: 0.7810 - val_loss: 0.8613 - val_accuracy: 0.6985 - val_recall: 0.6148 - val_precision: 0.7576
# Epoch 4/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.9412 - accuracy: 0.6700 - recall: 0.5312 - precision: 0.7966 - val_loss: 0.8244 - val_accuracy: 0.7022 - val_recall: 0.6302 - val_precision: 0.7655
# Epoch 5/32
# 275/275 [==============================] - 10s 38ms/step - loss: 0.8804 - accuracy: 0.6827 - recall: 0.5457 - precision: 0.7956 - val_loss: 0.7932 - val_accuracy: 0.7149 - val_recall: 0.6530 - val_precision: 0.7660
# Epoch 6/32
# 275/275 [==============================] - 11s 38ms/step - loss: 0.8644 - accuracy: 0.6950 - recall: 0.5512 - precision: 0.8138 - val_loss: 0.7834 - val_accuracy: 0.7149 - val_recall: 0.6521 - val_precision: 0.7691
# Epoch 7/32
# 275/275 [==============================] - 10s 36ms/step - loss: 0.8080 - accuracy: 0.7060 - recall: 0.5740 - precision: 0.8274 - val_loss: 0.7747 - val_accuracy: 0.7195 - val_recall: 0.6858 - val_precision: 0.7568
# Epoch 8/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.8014 - accuracy: 0.7051 - recall: 0.5812 - precision: 0.8134 - val_loss: 0.7586 - val_accuracy: 0.7213 - val_recall: 0.6621 - val_precision: 0.7759
# Epoch 9/32
# 275/275 [==============================] - 10s 38ms/step - loss: 0.7854 - accuracy: 0.7142 - recall: 0.5840 - precision: 0.8172 - val_loss: 0.7581 - val_accuracy: 0.7250 - val_recall: 0.6630 - val_precision: 0.7820
# Epoch 10/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.7717 - accuracy: 0.7101 - recall: 0.5926 - precision: 0.8082 - val_loss: 0.7423 - val_accuracy: 0.7322 - val_recall: 0.6211 - val_precision: 0.8197
# Epoch 11/32
# 275/275 [==============================] - 10s 38ms/step - loss: 0.7406 - accuracy: 0.7278 - recall: 0.6022 - precision: 0.8295 - val_loss: 0.7325 - val_accuracy: 0.7341 - val_recall: 0.6740 - val_precision: 0.7856
# Epoch 12/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.7382 - accuracy: 0.7292 - recall: 0.6145 - precision: 0.8303 - val_loss: 0.7259 - val_accuracy: 0.7386 - val_recall: 0.6685 - val_precision: 0.7987
# Epoch 13/32
# 275/275 [==============================] - 11s 41ms/step - loss: 0.7228 - accuracy: 0.7337 - recall: 0.6172 - precision: 0.8309 - val_loss: 0.7153 - val_accuracy: 0.7413 - val_recall: 0.6831 - val_precision: 0.7962
# Epoch 14/32
# 275/275 [==============================] - 11s 39ms/step - loss: 0.7009 - accuracy: 0.7433 - recall: 0.6354 - precision: 0.8300 - val_loss: 0.7042 - val_accuracy: 0.7468 - val_recall: 0.6767 - val_precision: 0.7998
# Epoch 15/32
# 275/275 [==============================] - 10s 38ms/step - loss: 0.6962 - accuracy: 0.7406 - recall: 0.6263 - precision: 0.8400 - val_loss: 0.7052 - val_accuracy: 0.7477 - val_recall: 0.6821 - val_precision: 0.7960
# Epoch 16/32
# 275/275 [==============================] - 10s 38ms/step - loss: 0.6724 - accuracy: 0.7487 - recall: 0.6541 - precision: 0.8399 - val_loss: 0.6901 - val_accuracy: 0.7550 - val_recall: 0.6676 - val_precision: 0.8117
# Epoch 17/32
# 275/275 [==============================] - 10s 38ms/step - loss: 0.6782 - accuracy: 0.7483 - recall: 0.6450 - precision: 0.8470 - val_loss: 0.6873 - val_accuracy: 0.7495 - val_recall: 0.6940 - val_precision: 0.7896
# Epoch 18/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.6473 - accuracy: 0.7606 - recall: 0.6618 - precision: 0.8449 - val_loss: 0.6864 - val_accuracy: 0.7568 - val_recall: 0.6803 - val_precision: 0.8050
# Epoch 19/32
# 275/275 [==============================] - 11s 40ms/step - loss: 0.6452 - accuracy: 0.7574 - recall: 0.6627 - precision: 0.8382 - val_loss: 0.6778 - val_accuracy: 0.7550 - val_recall: 0.6730 - val_precision: 0.8193
# Epoch 20/32
# 275/275 [==============================] - 11s 41ms/step - loss: 0.6422 - accuracy: 0.7533 - recall: 0.6586 - precision: 0.8418 - val_loss: 0.6803 - val_accuracy: 0.7596 - val_recall: 0.6985 - val_precision: 0.7998
# Epoch 21/32
# 275/275 [==============================] - 11s 42ms/step - loss: 0.6269 - accuracy: 0.7619 - recall: 0.6777 - precision: 0.8494 - val_loss: 0.6844 - val_accuracy: 0.7541 - val_recall: 0.6913 - val_precision: 0.8057
# Epoch 22/32
# 275/275 [==============================] - 11s 41ms/step - loss: 0.6279 - accuracy: 0.7647 - recall: 0.6746 - precision: 0.8469 - val_loss: 0.6696 - val_accuracy: 0.7623 - val_recall: 0.7049 - val_precision: 0.8021
# Epoch 23/32
# 275/275 [==============================] - 10s 38ms/step - loss: 0.6193 - accuracy: 0.7733 - recall: 0.6814 - precision: 0.8530 - val_loss: 0.6636 - val_accuracy: 0.7596 - val_recall: 0.7086 - val_precision: 0.7979
# Epoch 24/32
# 275/275 [==============================] - 10s 38ms/step - loss: 0.6111 - accuracy: 0.7774 - recall: 0.6891 - precision: 0.8515 - val_loss: 0.6747 - val_accuracy: 0.7568 - val_recall: 0.7049 - val_precision: 0.8012
# Epoch 25/32
# 275/275 [==============================] - 10s 38ms/step - loss: 0.5987 - accuracy: 0.7820 - recall: 0.6932 - precision: 0.8571 - val_loss: 0.6522 - val_accuracy: 0.7614 - val_recall: 0.6940 - val_precision: 0.8055
# Epoch 26/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.5989 - accuracy: 0.7806 - recall: 0.6964 - precision: 0.8567 - val_loss: 0.6565 - val_accuracy: 0.7632 - val_recall: 0.7195 - val_precision: 0.7972
# Epoch 27/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.5866 - accuracy: 0.7820 - recall: 0.6919 - precision: 0.8520 - val_loss: 0.6576 - val_accuracy: 0.7559 - val_recall: 0.7077 - val_precision: 0.8060
# Epoch 28/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.5774 - accuracy: 0.7856 - recall: 0.7010 - precision: 0.8652 - val_loss: 0.6468 - val_accuracy: 0.7577 - val_recall: 0.7113 - val_precision: 0.8052
# Epoch 29/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.5729 - accuracy: 0.7911 - recall: 0.7064 - precision: 0.8565 - val_loss: 0.6489 - val_accuracy: 0.7568 - val_recall: 0.6940 - val_precision: 0.8176
# Epoch 30/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.5538 - accuracy: 0.7915 - recall: 0.7041 - precision: 0.8628 - val_loss: 0.6479 - val_accuracy: 0.7523 - val_recall: 0.6949 - val_precision: 0.8204
# Epoch 31/32
# 275/275 [==============================] - 10s 38ms/step - loss: 0.5593 - accuracy: 0.7915 - recall: 0.7069 - precision: 0.8628 - val_loss: 0.6507 - val_accuracy: 0.7587 - val_recall: 0.7195 - val_precision: 0.7948
# Epoch 32/32
# 275/275 [==============================] - 10s 38ms/step - loss: 0.5457 - accuracy: 0.7975 - recall: 0.7173 - precision: 0.8650 - val_loss: 0.6601 - val_accuracy: 0.7468 - val_recall: 0.6958 - val_precision: 0.8093

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Test Evaluate

# %%
y_true = np.argmax(y_test_one_hot, axis=1) 
y_pred = model.predict(X_test)  
y_pred = np.argmax(y_pred, axis=1)
# Out:
# 12/12 [==============================] - 2s 74ms/step

# %%
print(model.evaluate(X_test, y_test_one_hot))
# Out:
# 12/12 [==============================] - 1s 71ms/step - loss: 0.6571 - accuracy: 0.7684 - recall: 0.6975 - precision: 0.8232
# [0.6571417450904846, 0.7683923840522766, 0.6975476741790771, 0.8231511116027832]

# %%
class_names = ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR', 'Severe']
y_pred_probs = model.predict(X_test) 
y_pred = np.argmax(y_pred_probs, axis=1) 
y_true = np.argmax(y_test_one_hot, axis=1) 

# Buat Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(7,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 12/12 [==============================] - 1s 70ms/step

# %%
macro_f1 = f1_score(y_true, y_pred, average='macro')
print(f'Macro F1 Score: ', macro_f1)
# Out:
# Macro F1 Score:  0.5320737066197403

# %%
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#                 precision    recall  f1-score   support
#
#           Mild       0.95      0.94      0.94       181
#       Moderate       0.48      0.70      0.57        37
#          No_DR       0.66      0.79      0.72       100
# Proliferate_DR       1.00      0.11      0.19        19
#         Severe       0.38      0.17      0.23        30
#
#       accuracy                           0.77       367
#      macro avg       0.70      0.54      0.53       367
#   weighted avg       0.78      0.77      0.75       367
