# %% [markdown]
# # RESNET50

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import warnings
import seaborn as sns
import cv2 as cv2
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import confusion_matrix, f1_score, classification_report
warnings.filterwarnings('ignore')
tf.keras.backend.clear_session()

# %% [markdown]
# ## Load Images

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
df["id_code"] = df["id_code"].astype(str) + ".png"
label_map = dict(zip(df["id_code"], df["diagnosis"]))
dataset_path = 'colored_images'
X = []
y = []

# %%
df.head()
# Out:
#             id_code  diagnosis
# 0  000c1434d8d7.png          2
# 1  001639a390f0.png          4
# 2  0024cdab0c1e.png          1
# 3  002c21358ce6.png          0
# 4  005b95c28852.png          0

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):
        print(f"🔄 Loading images from {subfolder}...")

        for filename in tqdm(os.listdir(subfolder_path)):
            img_path = os.path.join(subfolder_path, filename)

          
            if filename in label_map:
                label = label_map[filename] 
                
                # Load gambar
                img = cv2.imread(img_path)
                if img is not None:
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    img = cv2.resize(img, (224, 224))  
                    X.append(img)
                    y.append(label) 

print(f"Total images loaded: {len(X)}")
print(f"Total labels loaded: {len(y)}")
# Out:
# 🔄 Loading images from Mild...
# 100%|██████████| 370/370 [00:00<00:00, 972.88it/s]
# 🔄 Loading images from Moderate...
# 100%|██████████| 999/999 [00:01<00:00, 898.54it/s]
# 🔄 Loading images from No_DR...
# 100%|██████████| 1805/1805 [00:01<00:00, 929.01it/s]
# 🔄 Loading images from Proliferate_DR...
# 100%|██████████| 295/295 [00:00<00:00, 859.58it/s]
# 🔄 Loading images from Severe...
# 100%|██████████| 193/193 [00:00<00:00, 848.54it/s]
# Total images loaded: 3662
# Total labels loaded: 3662

# %%
import random

random_indices = random.sample(range(len(X)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X[index])
    plt.title(f"Label: {y[index]}")
    plt.axis('off')
plt.show()

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):  # Cek apakah benar-benar folder
        count = len([name for name in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, name))])
        print(f'Jumlah gambar pada folder {subfolder}: {count}')
# Out:
# Jumlah gambar pada folder Mild: 370
# Jumlah gambar pada folder Moderate: 999
# Jumlah gambar pada folder No_DR: 1805
# Jumlah gambar pada folder Proliferate_DR: 295
# Jumlah gambar pada folder Severe: 193

# %% [markdown]
# ## Splitting Data

# %%
X = np.array(X)
y = np.array(y)

X_train, X_remainingdata, y_train, y_remainingdata = train_test_split(X, y, train_size=0.6, random_state=42, stratify=y)
X_valid, X_test, y_valid, y_test = train_test_split(X_remainingdata, y_remainingdata, test_size=0.25, random_state=42, stratify=y_remainingdata)

print(f"Ukuran data training: {len(X_train)}")
print(f"Ukuran data validasi: {len(X_valid)}")
print(f"Ukuran data testing: {len(X_test)}")
# Out:
# Ukuran data training: 2197
# Ukuran data validasi: 1098
# Ukuran data testing: 367

# %%
print(X_train.shape)
# Out:
# (2197, 224, 224, 3)

# %%
from collections import Counter
print("\nDistribusi kelas :")
print("Training:", Counter(y_train))
print("Validation:", Counter(y_valid))
print("Testing:", Counter(y_test))
# Out:
# Distribusi kelas :
# Training: Counter({0: 1083, 2: 599, 1: 222, 4: 177, 3: 116})
# Validation: Counter({0: 541, 2: 300, 1: 111, 4: 88, 3: 58})
# Testing: Counter({0: 181, 2: 100, 1: 37, 4: 30, 3: 19})

# %% [markdown]
# ## Preprocessing Image

# %%
def preprocess_image(image, target_size=(224, 224)):
    # Resize image to standard size
    resized_image = cv2.resize(image, target_size)

    # Gaussian Blur
    blurred = cv2.GaussianBlur(resized_image, (3, 3), sigmaX=0.3, sigmaY=0.3)

    # Create a mask for circular cropping
    height, width = blurred.shape[:2]
    mask = np.zeros((height, width), dtype=np.uint8)
    center = (width // 2, height // 2)
    radius = min(center) - 10  # Adjust radius as needed
    cv2.circle(mask, center, radius, (255), thickness=-1)

    # Apply the mask to the blurred image
    circular_cropped_image = cv2.bitwise_and(blurred, blurred, mask=mask)

    # Convert back to 3 channels
    processed_image = cv2.merge([circular_cropped_image[:, :, 0], circular_cropped_image[:, :, 1], circular_cropped_image[:, :, 2]])

    return processed_image

X_train_processed = np.array([preprocess_image(img) for img in X_train])
X_valid_processed = np.array([preprocess_image(img) for img in X_valid])
X_test_processed = np.array([preprocess_image(img) for img in X_test])

# %%
print("Shape X_train_processed:", X_train_processed.shape)
print("Shape X_valid_processed:", X_valid_processed.shape)
print("Shape X_test_processed:", X_test_processed.shape)
# Out:
# Shape X_train_processed: (2197, 224, 224, 3)
# Shape X_valid_processed: (1098, 224, 224, 3)
# Shape X_test_processed: (367, 224, 224, 3)

# %%
# Displaying sample preprocessed images
random_indices = random.sample(range(len(X_train_processed)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X_train_processed[index])
    plt.title(f"Label: {y_train[index]}")
    plt.axis('off')
plt.show()

# %%
n_samples = 5
sample_indices = np.random.choice(len(X), n_samples, replace=False)
sample_originals = [X[i] for i in sample_indices]
sample_processed = [preprocess_image(img) for img in sample_originals]

# Tampilkan hasil
plt.figure(figsize=(15, 4))
for i in range(n_samples):
    # Gambar original (atas)
    plt.subplot(2, n_samples, i + 1)
    #original_rgb = cv2.cvtColor(sample_originals[i], cv2.COLOR_BGR2RGB)
    plt.imshow(sample_originals[i])
    plt.title("Original")
    plt.axis("off")

    # Gambar hasil preprocess (bawah)
    plt.subplot(2, n_samples, i + 1 + n_samples)
    plt.imshow(sample_processed[i], cmap='gray')  # bisa juga hapus cmap biar full RGB grayscale
    plt.title("Gaussian")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import albumentations as A
def augment_image(image):
    # Definisikan augmentasi
    augmentations = A.Compose([
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.RandomRotate90(p=0.5),
        A.RandomBrightnessContrast(p=0.2),
        A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, p=0.5),
        A.GaussianBlur(blur_limit=(3, 7), p=0.5),
        A.Emboss(p=0.5),
        # Hapus RandomScale dan PadIfNeeded
    ])

    augmented = augmentations(image=image)['image']
    
    # Resize kembali ke ukuran yang diinginkan
    augmented_resized = cv2.resize(augmented, (224, 224))

    # Pastikan dimensi output konsisten
    if augmented_resized.shape != (224, 224, 3):
        raise ValueError(f"Output shape is not as expected: {augmented_resized.shape}")

    return augmented_resized

# %%
X_train_augmented = []

for image in X_train_processed:
    augmented_image = augment_image(image)
    X_train_augmented.append(augmented_image)

# Mengubah kembali ke array NumPy jika diperlukan
X_train_augmented = np.array(X_train_augmented)

# %% [markdown]
# ## Build Model ResNet50

# %%
n_class = 5

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
for layer in base_model.layers :
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(n_class, activation='softmax')(x)

adam = Adam(lr=1e-4)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision()])

# %%
from keras.utils import to_categorical

y_train_one_hot = to_categorical(y_train, num_classes=n_class)
y_valid_one_hot = to_categorical(y_valid, num_classes=n_class)
y_test_one_hot = to_categorical(y_test, num_classes=n_class )

# %%
print(X_train_augmented.shape)
print(y_train_one_hot.shape)
print(X_valid_processed.shape)
print(y_valid_one_hot.shape)
# Out:
# (2197, 224, 224, 3)
# (2197, 5)
# (1098, 224, 224, 3)
# (1098, 5)

# %%
es = EarlyStopping(monitor='val_loss', patience=5)
rlr = ReduceLROnPlateau(monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose=1,
    min_lr=1e-7)

# %%
history = model.fit(X_train_augmented,y_train_one_hot, epochs=32, batch_size=8, validation_data=(X_valid_processed, y_valid_one_hot))
# Out:
# Epoch 1/32
# 275/275 [==============================] - 149s 543ms/step - loss: 0.9851 - accuracy: 0.6431 - recall: 0.5289 - precision: 0.7449 - val_loss: 0.7880 - val_accuracy: 0.7195 - val_recall: 0.5774 - val_precision: 0.8298
# Epoch 2/32
# 275/275 [==============================] - 140s 511ms/step - loss: 0.8012 - accuracy: 0.7028 - recall: 0.5926 - precision: 0.8002 - val_loss: 0.7667 - val_accuracy: 0.6949 - val_recall: 0.5501 - val_precision: 0.8075
# Epoch 3/32
# 275/275 [==============================] - 142s 518ms/step - loss: 0.7024 - accuracy: 0.7342 - recall: 0.6400 - precision: 0.8151 - val_loss: 0.7017 - val_accuracy: 0.7304 - val_recall: 0.6111 - val_precision: 0.8472
# Epoch 4/32
# 275/275 [==============================] - 203s 738ms/step - loss: 0.6523 - accuracy: 0.7465 - recall: 0.6623 - precision: 0.8225 - val_loss: 0.7256 - val_accuracy: 0.7222 - val_recall: 0.6548 - val_precision: 0.7927
# Epoch 5/32
# 275/275 [==============================] - 152s 552ms/step - loss: 0.6278 - accuracy: 0.7629 - recall: 0.6900 - precision: 0.8298 - val_loss: 0.6908 - val_accuracy: 0.7304 - val_recall: 0.6785 - val_precision: 0.7875
# Epoch 6/32
# 275/275 [==============================] - 217s 792ms/step - loss: 0.5909 - accuracy: 0.7779 - recall: 0.7032 - precision: 0.8365 - val_loss: 0.6864 - val_accuracy: 0.7395 - val_recall: 0.6594 - val_precision: 0.8053
# Epoch 7/32
# 275/275 [==============================] - 185s 674ms/step - loss: 0.5568 - accuracy: 0.7843 - recall: 0.7173 - precision: 0.8598 - val_loss: 0.6515 - val_accuracy: 0.7559 - val_recall: 0.6812 - val_precision: 0.8256
# Epoch 8/32
# 275/275 [==============================] - 183s 666ms/step - loss: 0.5186 - accuracy: 0.7997 - recall: 0.7378 - precision: 0.8650 - val_loss: 0.6780 - val_accuracy: 0.7514 - val_recall: 0.7040 - val_precision: 0.7986
# Epoch 9/32
# 275/275 [==============================] - 224s 817ms/step - loss: 0.4799 - accuracy: 0.8175 - recall: 0.7538 - precision: 0.8711 - val_loss: 0.6548 - val_accuracy: 0.7495 - val_recall: 0.7067 - val_precision: 0.7935
# Epoch 10/32
# 275/275 [==============================] - 222s 808ms/step - loss: 0.4700 - accuracy: 0.8166 - recall: 0.7679 - precision: 0.8750 - val_loss: 0.6902 - val_accuracy: 0.7468 - val_recall: 0.7058 - val_precision: 0.7836
# Epoch 11/32
# 275/275 [==============================] - 216s 788ms/step - loss: 0.4383 - accuracy: 0.8352 - recall: 0.7761 - precision: 0.8825 - val_loss: 0.6570 - val_accuracy: 0.7413 - val_recall: 0.6785 - val_precision: 0.8115
# Epoch 12/32
# 275/275 [==============================] - 216s 786ms/step - loss: 0.4143 - accuracy: 0.8416 - recall: 0.7883 - precision: 0.8823 - val_loss: 0.6519 - val_accuracy: 0.7568 - val_recall: 0.7140 - val_precision: 0.7935
# Epoch 13/32
# 275/275 [==============================] - 235s 856ms/step - loss: 0.3833 - accuracy: 0.8507 - recall: 0.8084 - precision: 0.8938 - val_loss: 0.7535 - val_accuracy: 0.7486 - val_recall: 0.7350 - val_precision: 0.7657
# Epoch 14/32
# 275/275 [==============================] - 297s 1s/step - loss: 0.3709 - accuracy: 0.8662 - recall: 0.8239 - precision: 0.9045 - val_loss: 0.6830 - val_accuracy: 0.7404 - val_recall: 0.7177 - val_precision: 0.7888
# Epoch 15/32
# 275/275 [==============================] - 270s 984ms/step - loss: 0.3541 - accuracy: 0.8662 - recall: 0.8325 - precision: 0.9028 - val_loss: 0.6605 - val_accuracy: 0.7514 - val_recall: 0.7113 - val_precision: 0.7905
# Epoch 16/32
# 275/275 [==============================] - 272s 991ms/step - loss: 0.3058 - accuracy: 0.8935 - recall: 0.8616 - precision: 0.9239 - val_loss: 0.6643 - val_accuracy: 0.7614 - val_recall: 0.7350 - val_precision: 0.8006
# Epoch 17/32
# 275/275 [==============================] - 218s 794ms/step - loss: 0.2992 - accuracy: 0.8894 - recall: 0.8584 - precision: 0.9191 - val_loss: 0.6735 - val_accuracy: 0.7650 - val_recall: 0.7350 - val_precision: 0.7951
# Epoch 18/32
# 275/275 [==============================] - 209s 761ms/step - loss: 0.2660 - accuracy: 0.9122 - recall: 0.8848 - precision: 0.9324 - val_loss: 0.7111 - val_accuracy: 0.7532 - val_recall: 0.7213 - val_precision: 0.7818
# Epoch 19/32
# 275/275 [==============================] - 168s 612ms/step - loss: 0.2450 - accuracy: 0.9208 - recall: 0.8958 - precision: 0.9345 - val_loss: 0.8044 - val_accuracy: 0.7231 - val_recall: 0.7040 - val_precision: 0.7483
# Epoch 20/32
# 275/275 [==============================] - 159s 578ms/step - loss: 0.2365 - accuracy: 0.9162 - recall: 0.8876 - precision: 0.9361 - val_loss: 0.7230 - val_accuracy: 0.7532 - val_recall: 0.7268 - val_precision: 0.7733
# Epoch 21/32
# 275/275 [==============================] - 166s 605ms/step - loss: 0.2118 - accuracy: 0.9272 - recall: 0.9049 - precision: 0.9431 - val_loss: 0.7665 - val_accuracy: 0.7413 - val_recall: 0.7122 - val_precision: 0.7534
# Epoch 22/32
# 275/275 [==============================] - 210s 765ms/step - loss: 0.1905 - accuracy: 0.9349 - recall: 0.9199 - precision: 0.9488 - val_loss: 0.7443 - val_accuracy: 0.7486 - val_recall: 0.7313 - val_precision: 0.7743
# Epoch 23/32
# 275/275 [==============================] - 189s 689ms/step - loss: 0.1722 - accuracy: 0.9436 - recall: 0.9290 - precision: 0.9587 - val_loss: 0.8461 - val_accuracy: 0.7632 - val_recall: 0.7541 - val_precision: 0.7767
# Epoch 24/32
# 275/275 [==============================] - 176s 639ms/step - loss: 0.1684 - accuracy: 0.9408 - recall: 0.9290 - precision: 0.9533 - val_loss: 0.7948 - val_accuracy: 0.7705 - val_recall: 0.7568 - val_precision: 0.7810
# Epoch 25/32
# 275/275 [==============================] - 175s 639ms/step - loss: 0.1426 - accuracy: 0.9572 - recall: 0.9477 - precision: 0.9666 - val_loss: 0.8601 - val_accuracy: 0.7432 - val_recall: 0.7313 - val_precision: 0.7583
# Epoch 26/32
# 275/275 [==============================] - 225s 818ms/step - loss: 0.1338 - accuracy: 0.9563 - recall: 0.9472 - precision: 0.9634 - val_loss: 0.8595 - val_accuracy: 0.7459 - val_recall: 0.7413 - val_precision: 0.7600
# Epoch 27/32
# 275/275 [==============================] - 179s 650ms/step - loss: 0.1315 - accuracy: 0.9572 - recall: 0.9463 - precision: 0.9607 - val_loss: 0.9801 - val_accuracy: 0.7696 - val_recall: 0.7632 - val_precision: 0.7788
# Epoch 28/32
# 275/275 [==============================] - 207s 754ms/step - loss: 0.1132 - accuracy: 0.9645 - recall: 0.9577 - precision: 0.9732 - val_loss: 0.9549 - val_accuracy: 0.7322 - val_recall: 0.7222 - val_precision: 0.7425
# Epoch 29/32
# 275/275 [==============================] - 148s 540ms/step - loss: 0.1110 - accuracy: 0.9631 - recall: 0.9568 - precision: 0.9673 - val_loss: 0.9538 - val_accuracy: 0.7650 - val_recall: 0.7523 - val_precision: 0.7749
# Epoch 30/32
# 275/275 [==============================] - 217s 789ms/step - loss: 0.1029 - accuracy: 0.9609 - recall: 0.9577 - precision: 0.9682 - val_loss: 0.8866 - val_accuracy: 0.7395 - val_recall: 0.7231 - val_precision: 0.7576
# Epoch 31/32
# 275/275 [==============================] - 149s 542ms/step - loss: 0.0848 - accuracy: 0.9745 - recall: 0.9690 - precision: 0.9766 - val_loss: 0.8984 - val_accuracy: 0.7495 - val_recall: 0.7404 - val_precision: 0.7634
# Epoch 32/32
# 275/275 [==============================] - 173s 629ms/step - loss: 0.0770 - accuracy: 0.9791 - recall: 0.9741 - precision: 0.9830 - val_loss: 1.1497 - val_accuracy: 0.7696 - val_recall: 0.7650 - val_precision: 0.7756

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_train_true = np.argmax(y_train_one_hot, axis=1)

# Prediksi data training
y_train_pred_probs = model.predict(X_train_processed)
y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# Confusion matrix train
cm_train = confusion_matrix(y_train_true, y_train_pred)
labels = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']

# Plot
plt.figure(figsize=(7,6))
disp_train = ConfusionMatrixDisplay(confusion_matrix=cm_train, display_labels=labels)
disp_train.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix - Training Data')
plt.show()

# Classification Report
print("Classification Report (Train):")
print(classification_report(y_train_true, y_train_pred, target_names=labels))
# Out:
# 69/69 [==============================] - 95s 1s/step
# Classification Report (Train):
#                 precision    recall  f1-score   support
#
#          No_DR       0.96      0.99      0.97      1083
#           Mild       0.66      0.49      0.56       222
#       Moderate       0.65      0.91      0.76       599
#         Severe       0.76      0.14      0.23       116
# Proliferate_DR       0.83      0.27      0.41       177
#
#       accuracy                           0.81      2197
#      macro avg       0.77      0.56      0.59      2197
#   weighted avg       0.82      0.81      0.79      2197

# %% [markdown]
# ## Test Evaluate

# %%
print("Shape y_test_one_hot:", y_test_one_hot.shape)
print("Shape x_test_processed:", X_test_processed.shape)
# Out:
# Shape y_test_one_hot: (367, 5)
# Shape x_test_processed: (367, 224, 224, 3)

# %%
y_true = np.argmax(y_test_one_hot, axis=1) 
y_pred = model.predict(X_test_processed)  
y_pred = np.argmax(y_pred, axis=1)
# Out:
# 12/12 [==============================] - 13s 1s/step

# %%
print(model.evaluate(X_test_processed, y_test_one_hot))
# Out:
# 12/12 [==============================] - 14s 1s/step - loss: 1.1269 - accuracy: 0.7629 - recall: 0.7602 - precision: 0.7707
# [1.1268723011016846, 0.7629427909851074, 0.7602179646492004, 0.7707182168960571]

# %%
# Konversi one-hot label test ke label asli
y_test_true = np.argmax(y_test_one_hot, axis=1)

# Prediksi data test
y_test_pred_probs = model.predict(X_test_processed)
y_test_pred = np.argmax(y_test_pred_probs, axis=1)

# Confusion matrix test
cm_test = confusion_matrix(y_test_true, y_test_pred)

# Plot
plt.figure(figsize=(7,6))
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=labels)
disp_test.plot(cmap=plt.cm.Oranges, values_format='d')
plt.title('Confusion Matrix - Testing Data')
plt.show()

# Classification Report
print("Classification Report (Test):")
print(classification_report(y_test_true, y_test_pred, target_names=labels))
# Out:
# 12/12 [==============================] - 13s 1s/step
# Classification Report (Test):
#                 precision    recall  f1-score   support
#
#          No_DR       0.96      0.94      0.95       181
#           Mild       0.46      0.30      0.36        37
#       Moderate       0.61      0.92      0.73       100
#         Severe       0.43      0.16      0.23        19
# Proliferate_DR       0.50      0.10      0.17        30
#
#       accuracy                           0.76       367
#      macro avg       0.59      0.48      0.49       367
#   weighted avg       0.75      0.76      0.73       367

# %%
macro_f1 = f1_score(y_true, y_pred, average='macro')
print(f'Macro F1 Score: ', macro_f1)
# Out:
# Macro F1 Score:  0.4881793209707726

# %%
from glob import glob
image_paths = glob("test_images/*.png") + glob("test_images/*.jpg")
random.shuffle(image_paths)
image_paths = image_paths[:10]  # Increased sample size for better analysis
print(f"Ditemukan {len(image_paths)} gambar fundus")
# Out:
# Ditemukan 10 gambar fundus

# %%
# Pilih beberapa sample acak dari data test
sample_indices = random.sample(range(len(X_test_processed)), 5)
sample_images = X_test_processed[sample_indices]
sample_true_labels = y_test_true[sample_indices]
sample_pred_probs = model.predict(sample_images)
sample_pred_labels = np.argmax(sample_pred_probs, axis=1)
sample_confidences = np.max(sample_pred_probs, axis=1)

# Visualisasi hasil prediksi
plt.figure(figsize=(15, 5))
for i in range(5):
    img = sample_images[i]
    plt.subplot(1, 5, i + 1)
    plt.imshow(img)
    plt.title(f"True: {labels[sample_true_labels[i]]}\nPred: {labels[sample_pred_labels[i]]}\nConf: {sample_confidences[i]:.2%}")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 242ms/step
