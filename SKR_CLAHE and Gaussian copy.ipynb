# %% [markdown]
# # RESNET50

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import warnings
import seaborn as sns
import cv2 as cv2
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import confusion_matrix, f1_score, classification_report
warnings.filterwarnings('ignore')
tf.keras.backend.clear_session()

# %% [markdown]
# ## Load Images

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
df["id_code"] = df["id_code"].astype(str) + ".png"
label_map = dict(zip(df["id_code"], df["diagnosis"]))
dataset_path = 'colored_images'
X = []
y = []

# %%
df.head()
# Out:
#             id_code  diagnosis
# 0  000c1434d8d7.png          2
# 1  001639a390f0.png          4
# 2  0024cdab0c1e.png          1
# 3  002c21358ce6.png          0
# 4  005b95c28852.png          0

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):
        print(f"🔄 Loading images from {subfolder}...")

        for filename in tqdm(os.listdir(subfolder_path)):
            img_path = os.path.join(subfolder_path, filename)

          
            if filename in label_map:
                label = label_map[filename] 
                
                # Load gambar
                img = cv2.imread(img_path)
                if img is not None:
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    img = cv2.resize(img, (224, 224))  
                    X.append(img)
                    y.append(label) 

print(f"Total images loaded: {len(X)}")
print(f"Total labels loaded: {len(y)}")
# Out:
# 🔄 Loading images from Mild...
# 100%|██████████| 370/370 [00:00<00:00, 682.32it/s]
# 🔄 Loading images from Moderate...
# 100%|██████████| 999/999 [00:01<00:00, 677.21it/s]
# 🔄 Loading images from No_DR...
# 100%|██████████| 1805/1805 [00:02<00:00, 773.17it/s]
# 🔄 Loading images from Proliferate_DR...
# 100%|██████████| 295/295 [00:00<00:00, 706.31it/s]
# 🔄 Loading images from Severe...
# 100%|██████████| 193/193 [00:00<00:00, 714.94it/s]
# Total images loaded: 3662
# Total labels loaded: 3662

# %%
import random

random_indices = random.sample(range(len(X)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X[index])
    plt.title(f"Label: {y[index]}")
    plt.axis('off')
plt.show()

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):  # Cek apakah benar-benar folder
        count = len([name for name in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, name))])
        print(f'Jumlah gambar pada folder {subfolder}: {count}')
# Out:
# Jumlah gambar pada folder Mild: 370
# Jumlah gambar pada folder Moderate: 999
# Jumlah gambar pada folder No_DR: 1805
# Jumlah gambar pada folder Proliferate_DR: 295
# Jumlah gambar pada folder Severe: 193

# %% [markdown]
# ## Splitting Data

# %%
X = np.array(X)
y = np.array(y)

X_train, X_remainingdata, y_train, y_remainingdata = train_test_split(X, y, train_size=0.6, random_state=42, stratify=y)
X_valid, X_test, y_valid, y_test = train_test_split(X_remainingdata, y_remainingdata, test_size=0.25, random_state=42, stratify=y_remainingdata)

print(f"Ukuran data training: {len(X_train)}")
print(f"Ukuran data validasi: {len(X_valid)}")
print(f"Ukuran data testing: {len(X_test)}")
# Out:
# Ukuran data training: 2197
# Ukuran data validasi: 1098
# Ukuran data testing: 367

# %%
print(X_train.shape)
# Out:
# (2197, 224, 224, 3)

# %%
from collections import Counter
print("\nDistribusi kelas :")
print("Training:", Counter(y_train))
print("Validation:", Counter(y_valid))
print("Testing:", Counter(y_test))
# Out:
# Distribusi kelas :
# Training: Counter({0: 1083, 2: 599, 1: 222, 4: 177, 3: 116})
# Validation: Counter({0: 541, 2: 300, 1: 111, 4: 88, 3: 58})
# Testing: Counter({0: 181, 2: 100, 1: 37, 4: 30, 3: 19})

# %% [markdown]
# ## Preprocessing Image

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Ambil 1 gambar dari X_train (atau ganti index-nya kalau mau gambar lain)
sample_img = X_train[464]

# --- Original ---
original = sample_img

# --- Gaussian Only (warna tetap) ---
gaussian_blurred = cv2.GaussianBlur(sample_img, (3, 3), sigmaX=0.3, sigmaY=0.3)

# --- CLAHE + Gaussian ---
def preprocess_image(image):
    green_channel = image[:, :, 1]
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    enha = clahe.apply(green_channel)
    blurred = cv2.GaussianBlur(enha, (3, 3), sigmaX=0.3, sigmaY=0.3)
    processed_image = cv2.merge([blurred, blurred, blurred])
    return processed_image

clahe_gaussian = preprocess_image(sample_img)

# --- Plot ---
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
titles = ["Original", "Gaussian Only", "CLAHE + Gaussian"]

images = [original, gaussian_blurred, clahe_gaussian]

for i in range(3):
    axes[i].imshow(images[i])
    axes[i].set_title(titles[i])
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
print("Shape X_train_processed:", X_train_processed.shape)
print("Shape X_valid_processed:", X_valid_processed.shape)
print("Shape X_test_processed:", X_test_processed.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print("Shape X_train_processed:", X_train_processed.shape)
#       2 print("Shape X_valid_processed:", X_valid_processed.shape)
#       3 print("Shape X_test_processed:", X_test_processed.shape)
#
# NameError: name 'X_train_processed' is not defined

# %%
# Displaying sample preprocessed images
random_indices = random.sample(range(len(X_train_processed)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X_train_processed[index])
    plt.title(f"Label: {y_train[index]}")
    plt.axis('off')
plt.show()

# %%
n_samples = 5
sample_indices = np.random.choice(len(X), n_samples, replace=False)
sample_originals = [X[i] for i in sample_indices]
sample_processed = [preprocess_image(img) for img in sample_originals]

# Tampilkan hasil
plt.figure(figsize=(15, 4))
for i in range(n_samples):
    # Gambar original (atas)
    plt.subplot(2, n_samples, i + 1)
    #original_rgb = cv2.cvtColor(sample_originals[i], cv2.COLOR_BGR2RGB)
    plt.imshow(sample_originals[i])
    plt.title("Original")
    plt.axis("off")

    # Gambar hasil preprocess (bawah)
    plt.subplot(2, n_samples, i + 1 + n_samples)
    plt.imshow(sample_processed[i], cmap='gray')  # bisa juga hapus cmap biar full RGB grayscale
    plt.title("CLAHE + Gaussian")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Build Model ResNet50

# %%
n_class = 5

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
for layer in base_model.layers :
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(n_class, activation='softmax')(x)

adam = Adam(lr=1e-4)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision()])

# %%
from keras.utils import to_categorical

y_train_one_hot = to_categorical(y_train, num_classes=n_class)
y_valid_one_hot = to_categorical(y_valid, num_classes=n_class)
y_test_one_hot = to_categorical(y_test, num_classes=n_class )

# %%
print(X_train_processed.shape)
print(y_train_one_hot.shape)
print(X_valid_processed.shape)
print(y_valid_one_hot.shape)
# Out:
# (2197, 224, 224, 3)
# (2197, 5)
# (1098, 224, 224, 3)
# (1098, 5)

# %%
es = EarlyStopping(monitor='val_loss', patience=5)
rlr = ReduceLROnPlateau(monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose=1,
    min_lr=1e-7)

# %%
history = model.fit(X_train_processed,y_train_one_hot, epochs=32, batch_size=8, validation_data=(X_valid_processed, y_valid_one_hot), callbacks=[es, rlr])
# Out:
# Epoch 1/32
# 275/275 [==============================] - 54s 146ms/step - loss: 0.9675 - accuracy: 0.6586 - recall: 0.5303 - precision: 0.7570 - val_loss: 0.7129 - val_accuracy: 0.7313 - val_recall: 0.6202 - val_precision: 0.8407 - lr: 1.0000e-04
# Epoch 2/32
# 275/275 [==============================] - 55s 202ms/step - loss: 0.7131 - accuracy: 0.7365 - recall: 0.6386 - precision: 0.8148 - val_loss: 0.6491 - val_accuracy: 0.7541 - val_recall: 0.6913 - val_precision: 0.8153 - lr: 1.0000e-04
# Epoch 3/32
# 275/275 [==============================] - 55s 202ms/step - loss: 0.6560 - accuracy: 0.7497 - recall: 0.6714 - precision: 0.8069 - val_loss: 0.6339 - val_accuracy: 0.7559 - val_recall: 0.7122 - val_precision: 0.8070 - lr: 1.0000e-04
# Epoch 4/32
# 275/275 [==============================] - 39s 143ms/step - loss: 0.6098 - accuracy: 0.7724 - recall: 0.7037 - precision: 0.8325 - val_loss: 0.6291 - val_accuracy: 0.7732 - val_recall: 0.6849 - val_precision: 0.8300 - lr: 1.0000e-04
# Epoch 5/32
# 275/275 [==============================] - 47s 170ms/step - loss: 0.5729 - accuracy: 0.7852 - recall: 0.7164 - precision: 0.8426 - val_loss: 0.6144 - val_accuracy: 0.7732 - val_recall: 0.7204 - val_precision: 0.8163 - lr: 1.0000e-04
# Epoch 6/32
# 275/275 [==============================] - 43s 156ms/step - loss: 0.5528 - accuracy: 0.7888 - recall: 0.7378 - precision: 0.8382 - val_loss: 0.6037 - val_accuracy: 0.7842 - val_recall: 0.7222 - val_precision: 0.8295 - lr: 1.0000e-04
# Epoch 7/32
# 275/275 [==============================] - 47s 172ms/step - loss: 0.5232 - accuracy: 0.7956 - recall: 0.7574 - precision: 0.8425 - val_loss: 0.6000 - val_accuracy: 0.7823 - val_recall: 0.7322 - val_precision: 0.8187 - lr: 1.0000e-04
# Epoch 8/32
# 275/275 [==============================] - 42s 154ms/step - loss: 0.5051 - accuracy: 0.8084 - recall: 0.7579 - precision: 0.8491 - val_loss: 0.6057 - val_accuracy: 0.7805 - val_recall: 0.7295 - val_precision: 0.8275 - lr: 1.0000e-04
# Epoch 9/32
# 275/275 [==============================] - 38s 138ms/step - loss: 0.4916 - accuracy: 0.8229 - recall: 0.7647 - precision: 0.8589 - val_loss: 0.6156 - val_accuracy: 0.7750 - val_recall: 0.6949 - val_precision: 0.8357 - lr: 1.0000e-04
# Epoch 10/32
# 274/275 [============================>.] - ETA: 0s - loss: 0.4723 - accuracy: 0.8230 - recall: 0.7806 - precision: 0.8581
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 275/275 [==============================] - 52s 189ms/step - loss: 0.4720 - accuracy: 0.8229 - recall: 0.7806 - precision: 0.8579 - val_loss: 0.6036 - val_accuracy: 0.7832 - val_recall: 0.7386 - val_precision: 0.8234 - lr: 1.0000e-04
# Epoch 11/32
# 275/275 [==============================] - 48s 176ms/step - loss: 0.4249 - accuracy: 0.8398 - recall: 0.7988 - precision: 0.8766 - val_loss: 0.5703 - val_accuracy: 0.8060 - val_recall: 0.7559 - val_precision: 0.8300 - lr: 5.0000e-05
# Epoch 12/32
# 275/275 [==============================] - 34s 124ms/step - loss: 0.4135 - accuracy: 0.8466 - recall: 0.8034 - precision: 0.8812 - val_loss: 0.5839 - val_accuracy: 0.7842 - val_recall: 0.7423 - val_precision: 0.8274 - lr: 5.0000e-05
# Epoch 13/32
# 275/275 [==============================] - 55s 200ms/step - loss: 0.3951 - accuracy: 0.8512 - recall: 0.8120 - precision: 0.8880 - val_loss: 0.5937 - val_accuracy: 0.7805 - val_recall: 0.7377 - val_precision: 0.8165 - lr: 5.0000e-05
# Epoch 14/32
# 275/275 [==============================] - ETA: 0s - loss: 0.3814 - accuracy: 0.8534 - recall: 0.8170 - precision: 0.8864
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 275/275 [==============================] - 38s 139ms/step - loss: 0.3814 - accuracy: 0.8534 - recall: 0.8170 - precision: 0.8864 - val_loss: 0.5900 - val_accuracy: 0.7933 - val_recall: 0.7532 - val_precision: 0.8229 - lr: 5.0000e-05
# Epoch 15/32
# 275/275 [==============================] - 38s 140ms/step - loss: 0.3570 - accuracy: 0.8648 - recall: 0.8293 - precision: 0.8971 - val_loss: 0.5694 - val_accuracy: 0.7987 - val_recall: 0.7732 - val_precision: 0.8219 - lr: 2.5000e-05
# Epoch 16/32
# 275/275 [==============================] - 40s 145ms/step - loss: 0.3543 - accuracy: 0.8675 - recall: 0.8325 - precision: 0.8953 - val_loss: 0.5822 - val_accuracy: 0.8078 - val_recall: 0.7641 - val_precision: 0.8282 - lr: 2.5000e-05
# Epoch 17/32
# 275/275 [==============================] - 37s 136ms/step - loss: 0.3400 - accuracy: 0.8730 - recall: 0.8466 - precision: 0.9038 - val_loss: 0.5784 - val_accuracy: 0.8051 - val_recall: 0.7750 - val_precision: 0.8262 - lr: 2.5000e-05
# Epoch 18/32
# 274/275 [============================>.] - ETA: 0s - loss: 0.3302 - accuracy: 0.8732 - recall: 0.8408 - precision: 0.9043
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 275/275 [==============================] - 47s 172ms/step - loss: 0.3298 - accuracy: 0.8735 - recall: 0.8411 - precision: 0.9046 - val_loss: 0.6032 - val_accuracy: 0.7869 - val_recall: 0.7532 - val_precision: 0.8164 - lr: 2.5000e-05
# Epoch 19/32
# 275/275 [==============================] - 50s 183ms/step - loss: 0.3234 - accuracy: 0.8794 - recall: 0.8489 - precision: 0.9062 - val_loss: 0.5685 - val_accuracy: 0.8015 - val_recall: 0.7814 - val_precision: 0.8258 - lr: 1.2500e-05
# Epoch 20/32
# 275/275 [==============================] - 44s 160ms/step - loss: 0.3051 - accuracy: 0.8830 - recall: 0.8548 - precision: 0.9094 - val_loss: 0.5771 - val_accuracy: 0.8097 - val_recall: 0.7787 - val_precision: 0.8253 - lr: 1.2500e-05
# Epoch 21/32
# 275/275 [==============================] - 37s 135ms/step - loss: 0.3139 - accuracy: 0.8821 - recall: 0.8543 - precision: 0.9055 - val_loss: 0.5737 - val_accuracy: 0.7942 - val_recall: 0.7632 - val_precision: 0.8176 - lr: 1.2500e-05
# Epoch 22/32
# 273/275 [============================>.] - ETA: 0s - loss: 0.3012 - accuracy: 0.8933 - recall: 0.8640 - precision: 0.9200
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 275/275 [==============================] - 38s 139ms/step - loss: 0.3013 - accuracy: 0.8930 - recall: 0.8639 - precision: 0.9196 - val_loss: 0.5725 - val_accuracy: 0.8024 - val_recall: 0.7741 - val_precision: 0.8285 - lr: 1.2500e-05
# Epoch 23/32
# 275/275 [==============================] - 38s 139ms/step - loss: 0.2951 - accuracy: 0.8921 - recall: 0.8657 - precision: 0.9171 - val_loss: 0.5813 - val_accuracy: 0.8087 - val_recall: 0.7796 - val_precision: 0.8263 - lr: 6.2500e-06
# Epoch 24/32
# 275/275 [==============================] - 40s 145ms/step - loss: 0.2912 - accuracy: 0.8971 - recall: 0.8653 - precision: 0.9246 - val_loss: 0.5839 - val_accuracy: 0.8133 - val_recall: 0.7814 - val_precision: 0.8282 - lr: 6.2500e-06

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_train_true = np.argmax(y_train_one_hot, axis=1)

# Prediksi data training
y_train_pred_probs = model.predict(X_train_processed)
y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# Confusion matrix train
cm_train = confusion_matrix(y_train_true, y_train_pred)
labels = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']

# Plot
plt.figure(figsize=(7,6))
disp_train = ConfusionMatrixDisplay(confusion_matrix=cm_train, display_labels=labels)
disp_train.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix - Training Data')
plt.show()

# Classification Report
print("Classification Report (Train):")
print(classification_report(y_train_true, y_train_pred, target_names=labels))
# Out:
# 69/69 [==============================] - 22s 279ms/step
# Classification Report (Train):
#                 precision    recall  f1-score   support
#
#          No_DR       0.98      1.00      0.99      1083
#           Mild       0.82      0.76      0.79       222
#       Moderate       0.85      0.91      0.88       599
#         Severe       0.75      0.77      0.76       116
# Proliferate_DR       0.89      0.69      0.78       177
#
#       accuracy                           0.91      2197
#      macro avg       0.86      0.83      0.84      2197
#   weighted avg       0.91      0.91      0.91      2197

# %% [markdown]
# ## Test Evaluate

# %%
print("Shape y_test_one_hot:", y_test_one_hot.shape)
print("Shape x_test_processed:", X_test_processed.shape)
# Out:
# Shape y_test_one_hot: (367, 5)
# Shape x_test_processed: (367, 224, 224, 3)

# %%
y_true = np.argmax(y_test_one_hot, axis=1) 
y_pred = model.predict(X_test_processed)  
y_pred = np.argmax(y_pred, axis=1)
# Out:
# 12/12 [==============================] - 6s 586ms/step

# %%
print(model.evaluate(X_test_processed, y_test_one_hot))
# Out:
# 12/12 [==============================] - 4s 337ms/step - loss: 0.6011 - accuracy: 0.8093 - recall: 0.7738 - precision: 0.8402
# [0.6010951995849609, 0.8092643022537231, 0.7738419771194458, 0.8402366638183594]

# %%
# Konversi one-hot label test ke label asli
y_test_true = np.argmax(y_test_one_hot, axis=1)

# Prediksi data test
y_test_pred_probs = model.predict(X_test_processed)
y_test_pred = np.argmax(y_test_pred_probs, axis=1)

# Confusion matrix test
cm_test = confusion_matrix(y_test_true, y_test_pred)

# Plot
plt.figure(figsize=(7,6))
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=labels)
disp_test.plot(cmap=plt.cm.Oranges, values_format='d')
plt.title('Confusion Matrix - Testing Data')
plt.show()

# Classification Report
print("Classification Report (Test):")
print(classification_report(y_test_true, y_test_pred, target_names=labels))
# Out:
# 12/12 [==============================] - 9s 792ms/step
# Classification Report (Test):
#                 precision    recall  f1-score   support
#
#          No_DR       0.98      0.96      0.97       181
#           Mild       0.61      0.62      0.61        37
#       Moderate       0.71      0.86      0.78       100
#         Severe       0.54      0.37      0.44        19
# Proliferate_DR       0.44      0.27      0.33        30
#
#       accuracy                           0.81       367
#      macro avg       0.66      0.61      0.63       367
#   weighted avg       0.80      0.81      0.80       367

# %%
macro_f1 = f1_score(y_true, y_pred, average='macro')
print(f'Macro F1 Score: ', macro_f1)
# Out:
# Macro F1 Score:  0.6257855313160933

# %%
from glob import glob
image_paths = glob("test_images/*.png") + glob("test_images/*.jpg")
random.shuffle(image_paths)
image_paths = image_paths[:10]  # Increased sample size for better analysis
print(f"Ditemukan {len(image_paths)} gambar fundus")
# Out:
# Ditemukan 10 gambar fundus

# %%
# Pilih beberapa sample acak dari data test
sample_indices = random.sample(range(len(X_test_processed)), 5)
sample_images = X_test_processed[sample_indices]
sample_true_labels = y_test_true[sample_indices]
sample_pred_probs = model.predict(sample_images)
sample_pred_labels = np.argmax(sample_pred_probs, axis=1)
sample_confidences = np.max(sample_pred_probs, axis=1)

# Visualisasi hasil prediksi
plt.figure(figsize=(15, 5))
for i in range(5):
    img = sample_images[i]
    plt.subplot(1, 5, i + 1)
    plt.imshow(img)
    plt.title(f"True: {labels[sample_true_labels[i]]}\nPred: {labels[sample_pred_labels[i]]}\nConf: {sample_confidences[i]:.2%}")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
