# %% [markdown]
# # RESNET50

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import warnings
import seaborn as sns
import cv2 as cv2
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import confusion_matrix, f1_score, classification_report
warnings.filterwarnings('ignore')
tf.keras.backend.clear_session()

# %% [markdown]
# ## Load Images

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
df["id_code"] = df["id_code"].astype(str) + ".png"
label_map = dict(zip(df["id_code"], df["diagnosis"]))
dataset_path = 'colored_images'
X = []
y = []

# %%
df.head()
# Out:
#             id_code  diagnosis
# 0  000c1434d8d7.png          2
# 1  001639a390f0.png          4
# 2  0024cdab0c1e.png          1
# 3  002c21358ce6.png          0
# 4  005b95c28852.png          0

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):
        print(f"🔄 Loading images from {subfolder}...")

        for filename in tqdm(os.listdir(subfolder_path)):
            img_path = os.path.join(subfolder_path, filename)

          
            if filename in label_map:
                label = label_map[filename] 
                
                # Load gambar
                img = cv2.imread(img_path)
                if img is not None:
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    img = cv2.resize(img, (224, 224))  
                    X.append(img)
                    y.append(label) 

print(f"Total images loaded: {len(X)}")
print(f"Total labels loaded: {len(y)}")
# Out:
# 🔄 Loading images from Mild...
# 100%|██████████| 370/370 [00:00<00:00, 706.91it/s]
# 🔄 Loading images from Moderate...
# 100%|██████████| 999/999 [00:01<00:00, 721.11it/s]
# 🔄 Loading images from No_DR...
# 100%|██████████| 1805/1805 [00:02<00:00, 745.18it/s]
# 🔄 Loading images from Proliferate_DR...
# 100%|██████████| 295/295 [00:00<00:00, 726.50it/s]
# 🔄 Loading images from Severe...
# 100%|██████████| 193/193 [00:00<00:00, 722.60it/s]
# Total images loaded: 3662
# Total labels loaded: 3662

# %%
import random

random_indices = random.sample(range(len(X)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X[index])
    plt.title(f"Label: {y[index]}")
    plt.axis('off')
plt.show()

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):  # Cek apakah benar-benar folder
        count = len([name for name in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, name))])
        print(f'Jumlah gambar pada folder {subfolder}: {count}')
# Out:
# Jumlah gambar pada folder Mild: 370
# Jumlah gambar pada folder Moderate: 999
# Jumlah gambar pada folder No_DR: 1805
# Jumlah gambar pada folder Proliferate_DR: 295
# Jumlah gambar pada folder Severe: 193

# %% [markdown]
# ## Splitting Data

# %%
X = np.array(X)
y = np.array(y)

X_train, X_remainingdata, y_train, y_remainingdata = train_test_split(X, y, train_size=0.6, random_state=42, stratify=y)
X_valid, X_test, y_valid, y_test = train_test_split(X_remainingdata, y_remainingdata, test_size=0.25, random_state=42, stratify=y_remainingdata)

print(f"Ukuran data training: {len(X_train)}")
print(f"Ukuran data validasi: {len(X_valid)}")
print(f"Ukuran data testing: {len(X_test)}")
# Out:
# Ukuran data training: 2197
# Ukuran data validasi: 1098
# Ukuran data testing: 367

# %%
print(X_train.shape)
# Out:
# (2197, 224, 224, 3)

# %%
from collections import Counter
print("\nDistribusi kelas :")
print("Training:", Counter(y_train))
print("Validation:", Counter(y_valid))
print("Testing:", Counter(y_test))
# Out:
# Distribusi kelas :
# Training: Counter({0: 1083, 2: 599, 1: 222, 4: 177, 3: 116})
# Validation: Counter({0: 541, 2: 300, 1: 111, 4: 88, 3: 58})
# Testing: Counter({0: 181, 2: 100, 1: 37, 4: 30, 3: 19})

# %% [markdown]
# ## Build Model ResNet50

# %%
n_class = 5

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
for layer in base_model.layers: 
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(n_class, activation='softmax')(x)

adam = Adam(lr=0.00001)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision()])

# %%
from keras.utils import to_categorical

y_train_one_hot = to_categorical(y_train, num_classes=n_class)
y_valid_one_hot = to_categorical(y_valid, num_classes=n_class)
y_test_one_hot = to_categorical(y_test, num_classes=n_class )

# %%
print(X_train.shape)
print(y_train_one_hot.shape)
print(X_valid.shape)
print(y_valid_one_hot.shape)
# Out:
# (2197, 224, 224, 3)
# (2197, 5)
# (1098, 224, 224, 3)
# (1098, 5)

# %%
history = model.fit(X_train, y_train_one_hot, epochs=32, batch_size=8, validation_data=(X_valid, y_valid_one_hot))
# Out:
# Epoch 1/32
# 275/275 [==============================] - 18s 43ms/step - loss: 1.2816 - accuracy: 0.5344 - recall: 0.3154 - precision: 0.6501 - val_loss: 0.9751 - val_accuracy: 0.6694 - val_recall: 0.5000 - val_precision: 0.8182
# Epoch 2/32
# 275/275 [==============================] - 10s 37ms/step - loss: 1.0166 - accuracy: 0.6431 - recall: 0.4875 - precision: 0.7677 - val_loss: 0.8561 - val_accuracy: 0.6976 - val_recall: 0.5638 - val_precision: 0.7875
# Epoch 3/32
# 275/275 [==============================] - 11s 38ms/step - loss: 0.9219 - accuracy: 0.6768 - recall: 0.5448 - precision: 0.7870 - val_loss: 0.8074 - val_accuracy: 0.7104 - val_recall: 0.5883 - val_precision: 0.8005
# Epoch 4/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.8433 - accuracy: 0.7005 - recall: 0.5635 - precision: 0.8118 - val_loss: 0.7800 - val_accuracy: 0.7131 - val_recall: 0.6166 - val_precision: 0.7946
# Epoch 5/32
# 275/275 [==============================] - 12s 45ms/step - loss: 0.8054 - accuracy: 0.7096 - recall: 0.5776 - precision: 0.8093 - val_loss: 0.7585 - val_accuracy: 0.7177 - val_recall: 0.6585 - val_precision: 0.7867
# Epoch 6/32
# 275/275 [==============================] - 13s 46ms/step - loss: 0.7737 - accuracy: 0.7187 - recall: 0.6072 - precision: 0.8189 - val_loss: 0.7370 - val_accuracy: 0.7341 - val_recall: 0.6266 - val_precision: 0.8230
# Epoch 7/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.7465 - accuracy: 0.7219 - recall: 0.6108 - precision: 0.8188 - val_loss: 0.7200 - val_accuracy: 0.7341 - val_recall: 0.6694 - val_precision: 0.8077
# Epoch 8/32
# 275/275 [==============================] - 10s 37ms/step - loss: 0.7370 - accuracy: 0.7355 - recall: 0.6249 - precision: 0.8377 - val_loss: 0.7073 - val_accuracy: 0.7432 - val_recall: 0.6603 - val_precision: 0.8257
# Epoch 9/32
# 275/275 [==============================] - 12s 43ms/step - loss: 0.7093 - accuracy: 0.7392 - recall: 0.6336 - precision: 0.8261 - val_loss: 0.6990 - val_accuracy: 0.7495 - val_recall: 0.6566 - val_precision: 0.8384
# Epoch 10/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.7034 - accuracy: 0.7355 - recall: 0.6322 - precision: 0.8248 - val_loss: 0.6828 - val_accuracy: 0.7559 - val_recall: 0.6639 - val_precision: 0.8399
# Epoch 11/32
# 275/275 [==============================] - 14s 52ms/step - loss: 0.6776 - accuracy: 0.7510 - recall: 0.6563 - precision: 0.8408 - val_loss: 0.6740 - val_accuracy: 0.7505 - val_recall: 0.6931 - val_precision: 0.8245
# Epoch 12/32
# 275/275 [==============================] - 15s 54ms/step - loss: 0.6626 - accuracy: 0.7579 - recall: 0.6509 - precision: 0.8457 - val_loss: 0.6651 - val_accuracy: 0.7559 - val_recall: 0.7058 - val_precision: 0.8149
# Epoch 13/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.6435 - accuracy: 0.7624 - recall: 0.6755 - precision: 0.8342 - val_loss: 0.6579 - val_accuracy: 0.7623 - val_recall: 0.6803 - val_precision: 0.8384
# Epoch 14/32
# 275/275 [==============================] - 13s 48ms/step - loss: 0.6476 - accuracy: 0.7679 - recall: 0.6650 - precision: 0.8440 - val_loss: 0.6519 - val_accuracy: 0.7605 - val_recall: 0.7013 - val_precision: 0.8262
# Epoch 15/32
# 275/275 [==============================] - 13s 48ms/step - loss: 0.6360 - accuracy: 0.7697 - recall: 0.6791 - precision: 0.8540 - val_loss: 0.6436 - val_accuracy: 0.7659 - val_recall: 0.6995 - val_precision: 0.8303
# Epoch 16/32
# 275/275 [==============================] - 13s 46ms/step - loss: 0.6175 - accuracy: 0.7683 - recall: 0.6818 - precision: 0.8492 - val_loss: 0.6408 - val_accuracy: 0.7641 - val_recall: 0.7122 - val_precision: 0.8154
# Epoch 17/32
# 275/275 [==============================] - 12s 45ms/step - loss: 0.6095 - accuracy: 0.7797 - recall: 0.6891 - precision: 0.8411 - val_loss: 0.6383 - val_accuracy: 0.7687 - val_recall: 0.7049 - val_precision: 0.8199
# Epoch 18/32
# 275/275 [==============================] - 12s 45ms/step - loss: 0.5888 - accuracy: 0.7815 - recall: 0.7051 - precision: 0.8534 - val_loss: 0.6427 - val_accuracy: 0.7632 - val_recall: 0.6958 - val_precision: 0.8286
# Epoch 19/32
# 275/275 [==============================] - 13s 46ms/step - loss: 0.5920 - accuracy: 0.7797 - recall: 0.7010 - precision: 0.8527 - val_loss: 0.6359 - val_accuracy: 0.7705 - val_recall: 0.7067 - val_precision: 0.8282
# Epoch 20/32
# 275/275 [==============================] - 13s 46ms/step - loss: 0.5904 - accuracy: 0.7861 - recall: 0.7055 - precision: 0.8587 - val_loss: 0.6287 - val_accuracy: 0.7659 - val_recall: 0.7168 - val_precision: 0.8224
# Epoch 21/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.5855 - accuracy: 0.7838 - recall: 0.7055 - precision: 0.8465 - val_loss: 0.6239 - val_accuracy: 0.7696 - val_recall: 0.7168 - val_precision: 0.8215
# Epoch 22/32
# 275/275 [==============================] - 13s 46ms/step - loss: 0.5622 - accuracy: 0.7915 - recall: 0.7096 - precision: 0.8590 - val_loss: 0.6190 - val_accuracy: 0.7632 - val_recall: 0.7259 - val_precision: 0.8166
# Epoch 23/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.5714 - accuracy: 0.7852 - recall: 0.7223 - precision: 0.8455 - val_loss: 0.6147 - val_accuracy: 0.7723 - val_recall: 0.7113 - val_precision: 0.8273
# Epoch 24/32
# 275/275 [==============================] - 13s 48ms/step - loss: 0.5445 - accuracy: 0.7947 - recall: 0.7260 - precision: 0.8626 - val_loss: 0.6133 - val_accuracy: 0.7750 - val_recall: 0.7231 - val_precision: 0.8237
# Epoch 25/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.5558 - accuracy: 0.8006 - recall: 0.7246 - precision: 0.8573 - val_loss: 0.6112 - val_accuracy: 0.7723 - val_recall: 0.7204 - val_precision: 0.8283
# Epoch 26/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.5469 - accuracy: 0.7938 - recall: 0.7296 - precision: 0.8586 - val_loss: 0.6047 - val_accuracy: 0.7769 - val_recall: 0.7177 - val_precision: 0.8234
# Epoch 27/32
# 275/275 [==============================] - 14s 51ms/step - loss: 0.5273 - accuracy: 0.7952 - recall: 0.7351 - precision: 0.8641 - val_loss: 0.6072 - val_accuracy: 0.7796 - val_recall: 0.7240 - val_precision: 0.8247
# Epoch 28/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.5201 - accuracy: 0.8125 - recall: 0.7324 - precision: 0.8665 - val_loss: 0.6097 - val_accuracy: 0.7732 - val_recall: 0.7386 - val_precision: 0.8126
# Epoch 29/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.5345 - accuracy: 0.7979 - recall: 0.7383 - precision: 0.8605 - val_loss: 0.6018 - val_accuracy: 0.7796 - val_recall: 0.7295 - val_precision: 0.8241
# Epoch 30/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.5275 - accuracy: 0.8011 - recall: 0.7346 - precision: 0.8558 - val_loss: 0.6041 - val_accuracy: 0.7796 - val_recall: 0.7250 - val_precision: 0.8223
# Epoch 31/32
# 275/275 [==============================] - 14s 52ms/step - loss: 0.5116 - accuracy: 0.8097 - recall: 0.7437 - precision: 0.8650 - val_loss: 0.6055 - val_accuracy: 0.7796 - val_recall: 0.7295 - val_precision: 0.8215
# Epoch 32/32
# 275/275 [==============================] - 13s 47ms/step - loss: 0.5051 - accuracy: 0.8084 - recall: 0.7460 - precision: 0.8686 - val_loss: 0.5965 - val_accuracy: 0.7814 - val_recall: 0.7277 - val_precision: 0.8280

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Test Evaluate

# %%
y_true = np.argmax(y_test_one_hot, axis=1) 
y_pred = model.predict(X_test)  
y_pred = np.argmax(y_pred, axis=1)
# Out:
# 12/12 [==============================] - 3s 71ms/step

# %%
print(model.evaluate(X_test, y_test_one_hot))
# Out:
# 12/12 [==============================] - 1s 80ms/step - loss: 0.5872 - accuracy: 0.7847 - recall: 0.7302 - precision: 0.8349
# [0.58724445104599, 0.7847411632537842, 0.7302452325820923, 0.8348909616470337]

# %%
class_names = ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR', 'Severe']
y_pred_probs = model.predict(X_test) 
y_pred = np.argmax(y_pred_probs, axis=1) 
y_true = np.argmax(y_test_one_hot, axis=1) 

# Buat Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(7,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 12/12 [==============================] - 1s 75ms/step

# %%
macro_f1 = f1_score(y_true, y_pred, average='macro')
print(f'Macro F1 Score: ', macro_f1)
# Out:
# Macro F1 Score:  0.5393258633910845

# %%
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#                 precision    recall  f1-score   support
#
#           Mild       0.98      0.94      0.96       181
#       Moderate       0.56      0.51      0.54        37
#          No_DR       0.65      0.91      0.76       100
# Proliferate_DR       0.67      0.11      0.18        19
#         Severe       0.40      0.20      0.27        30
#
#       accuracy                           0.78       367
#      macro avg       0.65      0.53      0.54       367
#   weighted avg       0.78      0.78      0.76       367
