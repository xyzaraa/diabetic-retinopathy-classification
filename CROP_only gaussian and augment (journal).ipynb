# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import warnings
import cv2 as cv2
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
tf.keras.backend.clear_session()
from sklearn.metrics import confusion_matrix, f1_score
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Images

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
df["id_code"] = df["id_code"].astype(str) + ".png"
label_map = dict(zip(df["id_code"], df["diagnosis"]))
dataset_path = 'colored_images'
X = []
y = []

# %%
df.head()
# Out:
#             id_code  diagnosis
# 0  000c1434d8d7.png          2
# 1  001639a390f0.png          4
# 2  0024cdab0c1e.png          1
# 3  002c21358ce6.png          0
# 4  005b95c28852.png          0

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):
        print(f"🔄 Loading images from {subfolder}...")

        for filename in tqdm(os.listdir(subfolder_path)):
            img_path = os.path.join(subfolder_path, filename)

          
            if filename in label_map:
                label = label_map[filename] 
                
                # Load gambar
                img = cv2.imread(img_path)
                if img is not None:
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    img = cv2.resize(img, (224, 224))  
                    X.append(img)
                    y.append(label) 

print(f"Total images loaded: {len(X)}")
print(f"Total labels loaded: {len(y)}")
# Out:
# 🔄 Loading images from Mild...
# 100%|██████████| 370/370 [00:00<00:00, 865.46it/s]
# 🔄 Loading images from Moderate...
# 100%|██████████| 999/999 [00:01<00:00, 837.57it/s]
# 🔄 Loading images from No_DR...
# 100%|██████████| 1805/1805 [00:01<00:00, 939.54it/s]
# 🔄 Loading images from Proliferate_DR...
# 100%|██████████| 295/295 [00:00<00:00, 853.86it/s]
# 🔄 Loading images from Severe...
# 100%|██████████| 193/193 [00:00<00:00, 827.23it/s]
# Total images loaded: 3662
# Total labels loaded: 3662

# %%
import random

random_indices = random.sample(range(len(X)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X[index])
    plt.title(f"Label: {y[index]}")
    plt.axis('off')
plt.show()

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):  # Cek apakah benar-benar folder
        count = len([name for name in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, name))])
        print(f'Jumlah gambar pada folder {subfolder}: {count}')
# Out:
# Jumlah gambar pada folder Mild: 370
# Jumlah gambar pada folder Moderate: 999
# Jumlah gambar pada folder No_DR: 1805
# Jumlah gambar pada folder Proliferate_DR: 295
# Jumlah gambar pada folder Severe: 193

# %% [markdown]
# ## Splitting Data

# %%
X = np.array(X)
y = np.array(y)

X_train, X_remainingdata, y_train, y_remainingdata = train_test_split(X, y, train_size=0.6, random_state=42, stratify=y)
X_valid, X_test, y_valid, y_test = train_test_split(X_remainingdata, y_remainingdata, test_size=0.25, random_state=42, stratify=y_remainingdata)

print(f"Ukuran data training: {len(X_train)}")
print(f"Ukuran data validasi: {len(X_valid)}")
print(f"Ukuran data testing: {len(X_test)}")
# Out:
# Ukuran data training: 2197
# Ukuran data validasi: 1098
# Ukuran data testing: 367

# %%
print(X_train.shape)
# Out:
# (2197, 224, 224, 3)

# %%
from collections import Counter
print("\nDistribusi kelas :")
print("Training:", Counter(y_train))
print("Validation:", Counter(y_valid))
print("Testing:", Counter(y_test))
# Out:
# Distribusi kelas :
# Training: Counter({0: 1083, 2: 599, 1: 222, 4: 177, 3: 116})
# Validation: Counter({0: 541, 2: 300, 1: 111, 4: 88, 3: 58})
# Testing: Counter({0: 181, 2: 100, 1: 37, 4: 30, 3: 19})

# %% [markdown]
# ## Preprocessing Image

# %%
def preprocess_image(image):
    
    blurred = cv2.GaussianBlur(image, (3, 3), sigmaX=0.5, sigmaY=0.5)

    return blurred


X_train_processed = np.array([preprocess_image(img) for img in X_train])
X_valid_processed = np.array([preprocess_image(img) for img in X_valid])
X_test_processed = np.array([preprocess_image(img) for img in X_test])

# %%
print("Shape X_train_processed:", X_train_processed.shape)
print("Shape X_valid_processed:", X_valid_processed.shape)
print("Shape X_test_processed:", X_test_processed.shape)
# Out:
# Shape X_train_processed: (2197, 224, 224, 3)
# Shape X_valid_processed: (1098, 224, 224, 3)
# Shape X_test_processed: (367, 224, 224, 3)

# %%
# Displaying sample preprocessed images
random_indices = random.sample(range(len(X_train_processed)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X_train_processed[index])
    plt.title(f"Label: {y_train[index]}")
    plt.axis('off')
plt.show()

# %%
def circular_crop(image):
    height, width = image.shape[:2]
    mask = np.zeros((height, width), dtype=np.uint8)
    center = (width // 2, height // 2)
    radius = min(center) - 15

    cv2.circle(mask, center, radius, 255, thickness=-1)

    circular_cropped_image = cv2.bitwise_and(image, image, mask=mask)

    return circular_cropped_image


X_train_cropped = np.array([circular_crop(img) for img in X_train_processed])
X_valid_cropped = np.array([circular_crop(img) for img in X_valid_processed])
#X_test_cropped = np.array([circular_crop(img) for img in X_test_processed])

# %%
# Displaying sample preprocessed images
random_indices = random.sample(range(len(X_train_cropped)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X_train_cropped[index])
    plt.title(f"Label: {y_train[index]}")
    plt.axis('off')
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=30,
    width_shift_range=0.15,
    height_shift_range=0.15,
    brightness_range=[0.3, 0.6],
    zoom_range=0.15,
    shear_range=0.05,
    channel_shift_range=10,
    fill_mode='nearest'
)

valid_datagen=ImageDataGenerator(
    rescale=1./255
)

# %% [markdown]
# ## Build Model ResNet50

# %%
n_class = 5

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
for layer in base_model.layers:
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
predictions = Dense(n_class, activation='softmax')(x)

adam = Adam(lr=0.00001)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision()])

# %%
from keras.utils import to_categorical

y_train_one_hot = to_categorical(y_train, num_classes=n_class)
y_valid_one_hot = to_categorical(y_valid, num_classes=n_class)
y_test_one_hot = to_categorical(y_test, num_classes=n_class )

# %%
train_generator = train_datagen.flow(
    X_train_cropped, 
    y_train_one_hot,
    batch_size=8,
    shuffle=True
)

valid_generator = valid_datagen.flow(
    X_valid_cropped,
    y_valid_one_hot,
    batch_size=8,
    shuffle=False
)

# %%
history = model.fit(train_generator, epochs=20,validation_data=valid_generator)
# Out:
# Epoch 1/20
# 275/275 [==============================] - 24s 72ms/step - loss: 2.3123 - accuracy: 0.0528 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 2.0524 - val_accuracy: 0.0528 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 2/20
# 275/275 [==============================] - 18s 67ms/step - loss: 1.8579 - accuracy: 0.0528 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 1.6833 - val_accuracy: 0.0528 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 3/20
# 275/275 [==============================] - 19s 68ms/step - loss: 1.5763 - accuracy: 0.2431 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 1.4694 - val_accuracy: 0.2732 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 4/20
# 275/275 [==============================] - 19s 68ms/step - loss: 1.4208 - accuracy: 0.4333 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 1.3641 - val_accuracy: 0.4927 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 5/20
# 275/275 [==============================] - 19s 70ms/step - loss: 1.3480 - accuracy: 0.4929 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 1.3206 - val_accuracy: 0.4927 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 6/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.3169 - accuracy: 0.4929 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 1.3035 - val_accuracy: 0.4927 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 7/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.3041 - accuracy: 0.4929 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 1.2967 - val_accuracy: 0.4927 - val_recall: 0.0128 - val_precision: 0.7000
# Epoch 8/20
# 275/275 [==============================] - 19s 68ms/step - loss: 1.2986 - accuracy: 0.4929 - recall: 4.5517e-04 - precision: 1.0000 - val_loss: 1.2938 - val_accuracy: 0.4927 - val_recall: 0.1439 - val_precision: 0.5940
# Epoch 9/20
# 275/275 [==============================] - 20s 71ms/step - loss: 1.2960 - accuracy: 0.4929 - recall: 9.1033e-04 - precision: 0.6667 - val_loss: 1.2923 - val_accuracy: 0.4927 - val_recall: 0.2641 - val_precision: 0.5620
# Epoch 10/20
# 275/275 [==============================] - 19s 70ms/step - loss: 1.2946 - accuracy: 0.4929 - recall: 0.0378 - precision: 0.4770 - val_loss: 1.2913 - val_accuracy: 0.4927 - val_recall: 0.1767 - val_precision: 0.5656
# Epoch 11/20
# 275/275 [==============================] - 19s 70ms/step - loss: 1.2940 - accuracy: 0.4929 - recall: 4.5517e-04 - precision: 0.3333 - val_loss: 1.2909 - val_accuracy: 0.4927 - val_recall: 0.2086 - val_precision: 0.5518
# Epoch 12/20
# 275/275 [==============================] - 19s 70ms/step - loss: 1.2936 - accuracy: 0.4929 - recall: 4.5517e-04 - precision: 0.5000 - val_loss: 1.2908 - val_accuracy: 0.4927 - val_recall: 0.4344 - val_precision: 0.5129
# Epoch 13/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.2933 - accuracy: 0.4929 - recall: 0.0077 - precision: 0.5862 - val_loss: 1.2910 - val_accuracy: 0.4927 - val_recall: 0.4690 - val_precision: 0.4909
# Epoch 14/20
# 275/275 [==============================] - 19s 68ms/step - loss: 1.2935 - accuracy: 0.4929 - recall: 0.0282 - precision: 0.4882 - val_loss: 1.2910 - val_accuracy: 0.4927 - val_recall: 0.4736 - val_precision: 0.4915
# Epoch 15/20
# 275/275 [==============================] - 19s 70ms/step - loss: 1.2932 - accuracy: 0.4929 - recall: 0.1370 - precision: 0.4816 - val_loss: 1.2909 - val_accuracy: 0.4927 - val_recall: 0.4663 - val_precision: 0.4923
# Epoch 16/20
# 275/275 [==============================] - 21s 76ms/step - loss: 1.2933 - accuracy: 0.4929 - recall: 0.0228 - precision: 0.5319 - val_loss: 1.2908 - val_accuracy: 0.4927 - val_recall: 0.4608 - val_precision: 0.4966
# Epoch 17/20
# 275/275 [==============================] - 19s 70ms/step - loss: 1.2930 - accuracy: 0.4929 - recall: 0.0046 - precision: 0.7143 - val_loss: 1.2913 - val_accuracy: 0.4927 - val_recall: 0.4927 - val_precision: 0.4936
# Epoch 18/20
# 275/275 [==============================] - 20s 73ms/step - loss: 1.2932 - accuracy: 0.4929 - recall: 0.1639 - precision: 0.5217 - val_loss: 1.2909 - val_accuracy: 0.4927 - val_recall: 0.4690 - val_precision: 0.4914
# Epoch 19/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.2933 - accuracy: 0.4929 - recall: 0.0514 - precision: 0.4850 - val_loss: 1.2908 - val_accuracy: 0.4927 - val_recall: 0.4699 - val_precision: 0.4914
# Epoch 20/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.2930 - accuracy: 0.4929 - recall: 0.0123 - precision: 0.4655 - val_loss: 1.2909 - val_accuracy: 0.4927 - val_recall: 0.4736 - val_precision: 0.4920

# %%
#model.save('model_resnet50_V2_noaugment.keras')

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
print(model.evaluate(X_test_processed, y_test_one_hot))
# Out:
# 12/12 [==============================] - 2s 80ms/step - loss: 1.5031 - accuracy: 0.4932 - recall: 0.4741 - precision: 0.6421
# [1.5030723810195923, 0.4931880235671997, 0.47411444783210754, 0.6420664191246033]

# %%
import numpy as np

print("Distribusi label Train:", np.unique(y_train, return_counts=True))
print("Distribusi label Validasi:", np.unique(y_valid, return_counts=True))
print("Distribusi label Test:", np.unique(y_test, return_counts=True))
# Out:
# Distribusi label Train: (array([0, 1, 2, 3, 4]), array([1083,  222,  599,  116,  177], dtype=int64))
# Distribusi label Validasi: (array([0, 1, 2, 3, 4]), array([541, 111, 300,  58,  88], dtype=int64))
# Distribusi label Test: (array([0, 1, 2, 3, 4]), array([181,  37, 100,  19,  30], dtype=int64))
