# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import warnings
import cv2 as cv2
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
tf.keras.backend.clear_session()
from sklearn.metrics import confusion_matrix, f1_score
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Images

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
df["id_code"] = df["id_code"].astype(str) + ".png"
label_map = dict(zip(df["id_code"], df["diagnosis"]))
dataset_path = 'colored_images'
X = []
y = []

# %%
df.head()
# Out:
#             id_code  diagnosis
# 0  000c1434d8d7.png          2
# 1  001639a390f0.png          4
# 2  0024cdab0c1e.png          1
# 3  002c21358ce6.png          0
# 4  005b95c28852.png          0

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):
        print(f"🔄 Loading images from {subfolder}...")

        for filename in tqdm(os.listdir(subfolder_path)):
            img_path = os.path.join(subfolder_path, filename)

          
            if filename in label_map:
                label = label_map[filename] 
                
                # Load gambar
                img = cv2.imread(img_path)
                if img is not None:
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    img = cv2.resize(img, (224, 224))  
                    X.append(img)
                    y.append(label) 

print(f"Total images loaded: {len(X)}")
print(f"Total labels loaded: {len(y)}")
# Out:
# 🔄 Loading images from Mild...
# 100%|██████████| 370/370 [00:00<00:00, 854.83it/s]
# 🔄 Loading images from Moderate...
# 100%|██████████| 999/999 [00:01<00:00, 855.42it/s]
# 🔄 Loading images from No_DR...
# 100%|██████████| 1805/1805 [00:01<00:00, 945.54it/s]
# 🔄 Loading images from Proliferate_DR...
# 100%|██████████| 295/295 [00:00<00:00, 853.63it/s]
# 🔄 Loading images from Severe...
# 100%|██████████| 193/193 [00:00<00:00, 846.92it/s]
# Total images loaded: 3662
# Total labels loaded: 3662

# %%
import random

random_indices = random.sample(range(len(X)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X[index])
    plt.title(f"Label: {y[index]}")
    plt.axis('off')
plt.show()

# %%
for subfolder in os.listdir(dataset_path):
    subfolder_path = os.path.join(dataset_path, subfolder)

    if os.path.isdir(subfolder_path):  # Cek apakah benar-benar folder
        count = len([name for name in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, name))])
        print(f'Jumlah gambar pada folder {subfolder}: {count}')
# Out:
# Jumlah gambar pada folder Mild: 370
# Jumlah gambar pada folder Moderate: 999
# Jumlah gambar pada folder No_DR: 1805
# Jumlah gambar pada folder Proliferate_DR: 295
# Jumlah gambar pada folder Severe: 193

# %% [markdown]
# ## Splitting Data

# %%
X = np.array(X)
y = np.array(y)

X_train, X_remainingdata, y_train, y_remainingdata = train_test_split(X, y, train_size=0.6, random_state=42, stratify=y)
X_valid, X_test, y_valid, y_test = train_test_split(X_remainingdata, y_remainingdata, test_size=0.25, random_state=42, stratify=y_remainingdata)

print(f"Ukuran data training: {len(X_train)}")
print(f"Ukuran data validasi: {len(X_valid)}")
print(f"Ukuran data testing: {len(X_test)}")
# Out:
# Ukuran data training: 2197
# Ukuran data validasi: 1098
# Ukuran data testing: 367

# %%
print(X_train.shape)
# Out:
# (2197, 224, 224, 3)

# %%
from collections import Counter
print("\nDistribusi kelas :")
print("Training:", Counter(y_train))
print("Validation:", Counter(y_valid))
print("Testing:", Counter(y_test))
# Out:
# Distribusi kelas :
# Training: Counter({0: 1083, 2: 599, 1: 222, 4: 177, 3: 116})
# Validation: Counter({0: 541, 2: 300, 1: 111, 4: 88, 3: 58})
# Testing: Counter({0: 181, 2: 100, 1: 37, 4: 30, 3: 19})

# %% [markdown]
# ## Preprocessing Image

# %%
def preprocess_image(image):
    
    blurred = cv2.GaussianBlur(image, (3, 3), sigmaX=0.5, sigmaY=0.5)

    return blurred


X_train_processed = np.array([preprocess_image(img) for img in X_train])
X_valid_processed = np.array([preprocess_image(img) for img in X_valid])
X_test_processed = np.array([preprocess_image(img) for img in X_test])

# %%
print("Shape X_train_processed:", X_train_processed.shape)
print("Shape X_valid_processed:", X_valid_processed.shape)
print("Shape X_test_processed:", X_test_processed.shape)
# Out:
# Shape X_train_processed: (2197, 224, 224, 3)
# Shape X_valid_processed: (1098, 224, 224, 3)
# Shape X_test_processed: (367, 224, 224, 3)

# %%
# Displaying sample preprocessed images
random_indices = random.sample(range(len(X_train_processed)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X_train_processed[index])
    plt.title(f"Label: {y_train[index]}")
    plt.axis('off')
plt.show()

# %%
def circular_crop(image):
    height, width = image.shape[:2]
    mask = np.zeros((height, width), dtype=np.uint8)
    center = (width // 2, height // 2)
    radius = min(center) - 15

    cv2.circle(mask, center, radius, 255, thickness=-1)

    circular_cropped_image = cv2.bitwise_and(image, image, mask=mask)

    return circular_cropped_image


X_train_cropped = np.array([circular_crop(img) for img in X_train_processed])
X_valid_cropped = np.array([circular_crop(img) for img in X_valid_processed])
#X_test_cropped = np.array([circular_crop(img) for img in X_test_processed])

# %%
# Displaying sample preprocessed images
random_indices = random.sample(range(len(X_train_cropped)), 5)
plt.figure(figsize=(15, 8))
for i, index in enumerate(random_indices):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X_train_cropped[index])
    plt.title(f"Label: {y_train[index]}")
    plt.axis('off')
plt.show()

# %% [markdown]
# ## Build Model ResNet50

# %%
n_class = 5

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
for layer in base_model.layers:
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
predictions = Dense(n_class, activation='softmax')(x)

adam = Adam(lr=0.00001)
model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy', Recall(), Precision()])

# %%
from keras.utils import to_categorical

y_train_one_hot = to_categorical(y_train, num_classes=n_class)
y_valid_one_hot = to_categorical(y_valid, num_classes=n_class)
y_test_one_hot = to_categorical(y_test, num_classes=n_class )

# %%
early_stopping=EarlyStopping(monitor='val_loss', patience=3)
reduce_lr=ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# %%
history = model.fit(X_train,y_train_one_hot, epochs=20, batch_size=8, validation_data=(X_valid, y_valid_one_hot), callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/20
# 275/275 [==============================] - 16s 40ms/step - loss: 1.4090 - accuracy: 0.3896 - recall: 0.1020 - precision: 0.5103 - val_loss: 1.2386 - val_accuracy: 0.5410 - val_recall: 0.2823 - val_precision: 0.8356 - lr: 1.0000e-05
# Epoch 2/20
# 275/275 [==============================] - 9s 34ms/step - loss: 1.1719 - accuracy: 0.5926 - recall: 0.3705 - precision: 0.8596 - val_loss: 1.1185 - val_accuracy: 0.5993 - val_recall: 0.4180 - val_precision: 0.8547 - lr: 1.0000e-05
# Epoch 3/20
# 275/275 [==============================] - 9s 35ms/step - loss: 1.0765 - accuracy: 0.6400 - recall: 0.4492 - precision: 0.8711 - val_loss: 1.0441 - val_accuracy: 0.6530 - val_recall: 0.4572 - val_precision: 0.8655 - lr: 1.0000e-05
# Epoch 4/20
# 275/275 [==============================] - 9s 35ms/step - loss: 1.0111 - accuracy: 0.6741 - recall: 0.4843 - precision: 0.8672 - val_loss: 0.9903 - val_accuracy: 0.6685 - val_recall: 0.4827 - val_precision: 0.8632 - lr: 1.0000e-05
# Epoch 5/20
# 275/275 [==============================] - 10s 35ms/step - loss: 0.9625 - accuracy: 0.6905 - recall: 0.5016 - precision: 0.8657 - val_loss: 0.9500 - val_accuracy: 0.6885 - val_recall: 0.5000 - val_precision: 0.8512 - lr: 1.0000e-05
# Epoch 6/20
# 275/275 [==============================] - 9s 34ms/step - loss: 0.9236 - accuracy: 0.7019 - recall: 0.5212 - precision: 0.8551 - val_loss: 0.9175 - val_accuracy: 0.6976 - val_recall: 0.5155 - val_precision: 0.8398 - lr: 1.0000e-05
# Epoch 7/20
# 275/275 [==============================] - 9s 34ms/step - loss: 0.8924 - accuracy: 0.7105 - recall: 0.5339 - precision: 0.8512 - val_loss: 0.8916 - val_accuracy: 0.7067 - val_recall: 0.5273 - val_precision: 0.8367 - lr: 1.0000e-05
# Epoch 8/20
# 275/275 [==============================] - 10s 35ms/step - loss: 0.8663 - accuracy: 0.7160 - recall: 0.5503 - precision: 0.8508 - val_loss: 0.8700 - val_accuracy: 0.7149 - val_recall: 0.5410 - val_precision: 0.8331 - lr: 1.0000e-05
# Epoch 9/20
# 275/275 [==============================] - 10s 35ms/step - loss: 0.8446 - accuracy: 0.7201 - recall: 0.5649 - precision: 0.8454 - val_loss: 0.8518 - val_accuracy: 0.7195 - val_recall: 0.5483 - val_precision: 0.8350 - lr: 1.0000e-05
# Epoch 10/20
# 275/275 [==============================] - 10s 35ms/step - loss: 0.8257 - accuracy: 0.7219 - recall: 0.5676 - precision: 0.8489 - val_loss: 0.8364 - val_accuracy: 0.7204 - val_recall: 0.5610 - val_precision: 0.8291 - lr: 1.0000e-05
# Epoch 11/20
# 275/275 [==============================] - 9s 34ms/step - loss: 0.8095 - accuracy: 0.7233 - recall: 0.5794 - precision: 0.8538 - val_loss: 0.8229 - val_accuracy: 0.7231 - val_recall: 0.5692 - val_precision: 0.8267 - lr: 1.0000e-05
# Epoch 12/20
# 275/275 [==============================] - 9s 34ms/step - loss: 0.7947 - accuracy: 0.7255 - recall: 0.5913 - precision: 0.8496 - val_loss: 0.8110 - val_accuracy: 0.7240 - val_recall: 0.5738 - val_precision: 0.8257 - lr: 1.0000e-05
# Epoch 13/20
# 275/275 [==============================] - 9s 34ms/step - loss: 0.7813 - accuracy: 0.7274 - recall: 0.5954 - precision: 0.8555 - val_loss: 0.8006 - val_accuracy: 0.7231 - val_recall: 0.5838 - val_precision: 0.8250 - lr: 1.0000e-05
# Epoch 14/20
# 275/275 [==============================] - 9s 34ms/step - loss: 0.7695 - accuracy: 0.7301 - recall: 0.6004 - precision: 0.8548 - val_loss: 0.7913 - val_accuracy: 0.7231 - val_recall: 0.5920 - val_precision: 0.8228 - lr: 1.0000e-05
# Epoch 15/20
# 275/275 [==============================] - 9s 35ms/step - loss: 0.7588 - accuracy: 0.7301 - recall: 0.6177 - precision: 0.8481 - val_loss: 0.7829 - val_accuracy: 0.7268 - val_recall: 0.5883 - val_precision: 0.8335 - lr: 1.0000e-05
# Epoch 16/20
# 275/275 [==============================] - 9s 34ms/step - loss: 0.7490 - accuracy: 0.7333 - recall: 0.6122 - precision: 0.8480 - val_loss: 0.7750 - val_accuracy: 0.7286 - val_recall: 0.5938 - val_precision: 0.8264 - lr: 1.0000e-05
# Epoch 17/20
# 275/275 [==============================] - 9s 35ms/step - loss: 0.7398 - accuracy: 0.7396 - recall: 0.6122 - precision: 0.8534 - val_loss: 0.7679 - val_accuracy: 0.7277 - val_recall: 0.6020 - val_precision: 0.8273 - lr: 1.0000e-05
# Epoch 18/20
# 275/275 [==============================] - 10s 35ms/step - loss: 0.7313 - accuracy: 0.7406 - recall: 0.6240 - precision: 0.8447 - val_loss: 0.7613 - val_accuracy: 0.7341 - val_recall: 0.5965 - val_precision: 0.8344 - lr: 1.0000e-05
# Epoch 19/20
# 275/275 [==============================] - 10s 35ms/step - loss: 0.7232 - accuracy: 0.7460 - recall: 0.6222 - precision: 0.8549 - val_loss: 0.7553 - val_accuracy: 0.7368 - val_recall: 0.6102 - val_precision: 0.8313 - lr: 1.0000e-05
# Epoch 20/20
# 275/275 [==============================] - 10s 35ms/step - loss: 0.7164 - accuracy: 0.7456 - recall: 0.6345 - precision: 0.8479 - val_loss: 0.7500 - val_accuracy: 0.7377 - val_recall: 0.6184 - val_precision: 0.8260 - lr: 1.0000e-05

# %%
#model.save('model_resnet50_V2_noaugment.keras')

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
print(model.evaluate(X_test_processed, y_test_one_hot))
# Out:
# 12/12 [==============================] - 1s 84ms/step - loss: 0.7771 - accuracy: 0.7248 - recall: 0.6213 - precision: 0.8261
# [0.7771257162094116, 0.7247956395149231, 0.6212534308433533, 0.8260869383811951]

# %%
import numpy as np

print("Distribusi label Train:", np.unique(y_train, return_counts=True))
print("Distribusi label Validasi:", np.unique(y_valid, return_counts=True))
print("Distribusi label Test:", np.unique(y_test, return_counts=True))
# Out:
# Distribusi label Train: (array([0, 1, 2, 3, 4]), array([1083,  222,  599,  116,  177], dtype=int64))
# Distribusi label Validasi: (array([0, 1, 2, 3, 4]), array([541, 111, 300,  58,  88], dtype=int64))
# Distribusi label Test: (array([0, 1, 2, 3, 4]), array([181,  37, 100,  19,  30], dtype=int64))
